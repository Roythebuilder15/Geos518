# %%
for i in np.arange(Nt):     #14601 times steps? 
    for j in np.arange(Nz): #33 rows
        
        # Check if we are at the initial time
        if(i==0): 
            if(j==0): #inital time step?
                T0zm1_15 = Ttop_15[i] #air temp? time zero minus 1             
                T0z_15   = Ts0_15[j]        #
                T0zp1_15 = Ts0_15[j+1]
                                
            elif((j>0) and (j<(Nz-1))): #
                T0zm1_15 = Ts0_15[j-1]            
                T0z_15   = Ts0_15[j]      
                T0zp1_15 = Ts0_15[j+1]
                
                
            elif(j==(Nz-1)):           #
                T0zm1_15 = Ts0_15[j-1]   
                T0z_15   = Ts0_15[j]     
                T0zp1_15 = Tbottom #
                
        else:
            if(j==0):                   #
                T0zm1_15 = Ttop_15[i]
                T0z_15   = Ts_15[j,i-1]
                T0zp1_15 = Ts_15[j+1,i-1]
                
                
            elif((j>0) and (j<(Nz-1))): #
                T0zm1_15 = Ts_15[j-1,i-1]
                T0z_15   = Ts_15[j,i-1]   
                T0zp1_15 = Ts_15[j+1,i-1]
                
                
            elif(j==(Nz-1)):            #
                T0zm1_15 = Ts_15[j-1,i-1]   
                T0z_15   = Ts_15[j,i-1]    
                T0zp1_15 = Tbottom
                

Tz_15 = s*T0zm1_15 + (1.0 - 2.0*s)*T0z_15 + s*T0zp1_15  #computes next temp? 0=temp at previous time, zm1=z minus 1, zp1=z plus 1 
Ts_15[j,i] = Tz_15

print(Ts_15.size)
print(Tz_15.size)

# %%
for i in np.arange(Nt):     #14601 times steps? 
    for j in np.arange(Nz): #33 rows
        
        # Check if we are at the initial time
        if(i==0): 
            if(j==0): #inital time step?
                T0zm1_30 = Ttop_30[i] #air temp? time zero minus 1             
                T0z_30   = Ts0_30[j]        #
                T0zp1_30 = Ts0_30[j+1]
                                
            elif((j>0) and (j<(Nz-1))): #
                T0zm1_30 = Ts0_30[j-1]            
                T0z_30   = Ts0_30[j]      
                T0zp1_30 = Ts0_30[j+1]
                
                
            elif(j==(Nz-1)):           #
                T0zm1_30 = Ts0_30[j-1]   
                T0z_30   = Ts0_30[j]     
                T0zp1_30 = Tbottom #
                
        else:
            if(j==0):                   #
                T0zm1_30 = Ttop_30[i]
                T0z_30   = Ts_30[j,i-1]
                T0zp1_30 = Ts_30[j+1,i-1]
                
                
            elif((j>0) and (j<(Nz-1))): #
                T0zm1_30 = Ts_30[j-1,i-1]
                T0z_30   = Ts_30[j,i-1]   
                T0zp1_30 = Ts_30[j+1,i-1]
                
                
            elif(j==(Nz-1)):            #
                T0zm1_30 = Ts_30[j-1,i-1]   
                T0z_30   = Ts_30[j,i-1]    
                T0zp1_30 = Tbottom
                

Tz_30 = s*T0zm1_30 + (1.0 - 2.0*s)*T0z_30 + s*T0zp1_30  #computes next temp? 0=temp at previous time, zm1=z minus 1, zp1=z plus 1 
Ts_30[j,i] = Tz_30

print(Ts_30.size)
print(Tz_30.size)

# %%
for i in np.arange(Nt):     #14601 times steps? 
    for j in np.arange(Nz): #33 rows
        
        # Check if we are at the initial time
        if(i==0): 
            if(j==0): #inital time step?
                T0zm1_45 = Ttop_45[i] #air temp? time zero minus 1             
                T0z_45   = Ts0_45[j]        #
                T0zp1_45 = Ts0_45[j+1]
                                
            elif((j>0) and (j<(Nz-1))): #
                T0zm1_45 = Ts0_45[j-1]            
                T0z_45   = Ts0_45[j]      
                T0zp1_45 = Ts0_5[j+1]
                
                
            elif(j==(Nz-1)):           #
                T0zm1_45 = Ts0_45[j-1]   
                T0z_45   = Ts0_45[j]     
                T0zp1_45 = Tbottom #
                
        else:
            if(j==0):                   #
                T0zm1_45 = Ttop_45[i]
                T0z_45   = Ts_45[j,i-1]
                T0zp1_45 = Ts_45[j+1,i-1]
                
                
            elif((j>0) and (j<(Nz-1))): #
                T0zm1_45 = Ts_45[j-1,i-1]
                T0z_45   = Ts_45[j,i-1]   
                T0zp1_45 = Ts_45[j+1,i-1]
                
                
            elif(j==(Nz-1)):            #
                T0zm1_45 = Ts_45[j-1,i-1]   
                T0z_45   = Ts_45[j,i-1]    
                T0zp1_45 = Tbottom
                

Tz_45 = s*T0zm1_45 + (1.0 - 2.0*s)*T0z_45 + s*T0zp1_45  #computes next temp? 0=temp at previous time, zm1=z minus 1, zp1=z plus 1 
Ts_45[j,i] = Tz_45

print(Ts_45.size)
print(Tz_45.size)
